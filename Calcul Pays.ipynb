# %% [markdown]
# <br>
# <b><font size=22>Odyssee - Process pays</font></b>
#
#
# # Usage
#
# Ce notebook permet de lancer l'intégralité du calcul d'un pays (Brute, coeff, tep, ges, ...)
#
# * Il suffit de changer les variables puis d'éxecuter le notebook entier.
# * Pour lancer plusieurs pays utilisé plutôt le launcher
# * la sortie va dans le sous répertoire out, un notebook de résultat au nom du pays.

# %%
import papermill as pm

# %% [markdown]
# # Variables

# %%
# pays à traiter - Si besoin de lancer plusieurs pays, utiliser plutôt le launcher
pays = "irl"

# début et fin
anneedeb = 1990
anneedef = 2020
# année MAJ
annee1 = 2020
annee2 = 2021

# %% [markdown]
# # Execution

# %%
#Importation des données Eurostat et GED (à finir)

#Calculs

out = "out/" + pays + ".OdyC.ipynb"
pm.execute_notebook("Odyssée.ipynb", out, parameters=dict(pays=pays,anneede=anneedeb,anneedef=anneedef))

# out = "out/" + pays + ".OdyTest.ipynb"
# pm.execute_notebook("test/CompareProcessODY.ipynb", out, parameters=dict(pays=pays,anneede=anneedeb,anneedef=anneedef))
# Out:
# Executing:   0%|          | 0/99 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'markdown',
#    'id': 'ae7757f1',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2022-08-02T08:13:20.418248',
#      'end_time': '2022-08-02T08:13:20.506762',
#      'duration': 0.088514,
#      'status': 'completed'}},
#    'source': '<br>\n<b><font size=22>Odyssee - Process Calcul Pays</font></b>\n\n\n**Année : 2020**'},
#   {'cell_type': 'markdown',
#    'id': 'f903737d',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2022-08-02T08:13:20.592744',
#      'end_time': '2022-08-02T08:13:20.681832',
#      'duration': 0.089088,
#      'status': 'completed'}},
#    'source': "# Définitions et Usages.\n\n\nIci on définit les imports nécessaires au code dans un premier bloc puis les variables spécifiques du traitements.\n\n## Usage :\n\nMode d'emploi du NB rapide:\n1. xxxxxx\n2. xxxx\n"},
#   {'cell_type': 'markdown',
# ...
