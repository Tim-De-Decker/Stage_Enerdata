# %%
import re
from sqlalchemy import create_engine

# %%
# Accès à Oracle 
odydb = create_engine('oracle://nrdb:acc#nr21@srvoraclecoll.grenoble.enerdata.net:1521/sodyssee')
odydb2 = create_engine('oracle://nrdb:acc#nr21@srvoraclecoll.grenoble.enerdata.net:1521/codyssee')

# Requête
qener2 = "WITH groups AS (SELECT code_serie, unite, code_pays , ROW_NUMBER() OVER (PARTITION BY code_serie ORDER BY CODE_PAYS DESC) AS row_nb FROM SERIES s) SELECT code_serie, unite FROM groups WHERE groups.row_nb = 1"

# Récupération des codes séries et des unités
seriesOdyC = pd.read_sql_query(qener2, odydb2)

seriesOdyC.columns = ["serie", "unite"]

seriesOdyS = pd.read_sql_query(qener2, odydb)

seriesOdyS.columns = ["serie", "unite"]

# %% [markdown]
# ## Regex

# %%
# Les variables suivantes consistent en des expressions régulières.
# Elles serviront à repérer et distinguer les fonctions appelées dans le fichier source.

affectation_serie = re.compile("CALC_DATA\.Affectation_Serie.?\(.+")
affectation_serie_mult = re.compile("CALC_DATA\.Affectation_Serie_MULT_UNIT\(.+")
affectation_serie_div = re.compile("CALC_DATA\.Affectation_Serie_DIV_UNIT\(.+")

serie_tep = re.compile("CALC_DATA\.Calcul_Serie_TEP\(.+")
serie_ele = re.compile("CALC_DATA\.Calcul_Serie_ELE\(.+")
serie_cs_tep = re.compile("CALC_DATA\.Calcul_Serie_CS_TEP\(.+")

serie_tkbr = re.compile("CALC_DATA\.Calcul_Serie_TKBR\(.+")
serie_flvtep = re.compile("CALC_DATA\.Calcul_Serie_FLVTEP\(.+")
serie_toccfado = re.compile("CALC_DATA\.Calcul_Serie_TOCCFADO\(.+")
serie_cfferxxx = re.compile("CALC_DATA\.Calcul_Serie_CFFERxxx\(.+")
serie_vpcun = re.compile("CALC_DATA\.Calcul_Serie_VPCUN\(.+")
serie_cfappels = re.compile("CALC_DATA\.Calcul_Serie_CFAppELS\(.+")
serie_cicc = re.compile("CALC_DATA\.Calcul_Serie_CICC\(.+")
serie_csvpcvkm = re.compile("CALC_DATA\.Calcul_Serie_CSVPCVKM\(.+")
serie_csvpcxxx = re.compile("CALC_DATA\.Calcul_Serie_CSVPCxxx\(.+")
serie_csvpcth = re.compile("CALC_DATA\.Calcul_Serie_CSVPCTH\(.+")

corr_clim = re.compile("CALC_DATA\.Calcul_Corr_Clim\(.+")
corr_clim_chf = re.compile("CALC_DATA\.Calcul_Corr_Clim_Chf\(.+")
corr_clim_ce = re.compile("CALC_DATA\.Calcul_Corr_Clim_CE\(.+")

serie_Base = re.compile("CALC_ECO\.Calcul_Serie_Base\(.+")
series_lc = re.compile("CALC_ECO\.Calcul_Series_LC_EURO\(.+")
ratio_base_100 = re.compile("CALC_ECO\.Calcul_Ratio_base_100\(.+")

affectation_serie_ody = re.compile("CALC_AGREGAT_ENERGIE\.Affectation_Serie_ODY\(.+")
reaffectation_serie_ody = re.compile("CALC_AGREGAT_ENERGIE\.Reaffectation_Serie_ODY\(.+")
serie_gaz = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_GAZ\(.+")
serie_toc = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_TOC\(.+")
serie_cmb = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_CMB\(.+")
serie_cmbec = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_CMBEC\(.+")
serie_cmbecind = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_CMBECIND\(.+")
serie_cmbec_eea = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_CMBEC_EEA\(.+")
serie_pet = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_PET\(.+")
serie_cms = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_CMS\(.+")
serie_tceec = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_TCEEC\(.+")
serie_ectot = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_ECTOT\(.+")
serie_toccp = re.compile("CALC_AGREGAT_ENERGIE\.Calcul_Serie_TOCCP\(.+")

serie_cfmpr = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFMPR\(.+")
serie_cfven = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFVEN\(.+")               
serie_cfretcc = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFRETCC\(.+") 
serie_cfresels1 = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFRESELS1\(.+") 
serie_cfvencc = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFVENCC\(.+")  
serie_cfroudom = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFROUDOM\(.+") 
serie_cftradom = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFTRADOM\(.+")
serie_cfretce = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFRETCE\(.+") 
serie_cfvence = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFVENCE\(.+") 
serie_cfpas = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFPAS\(.+")  
serie_ecpas = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_ECPAS\(.+")
serie_cffermch = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFFERMCH\(.+")
serie_cfmch = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFMCH\(.+")
serie_cfima = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_CFIMA\(.+")  
serie_resdiv = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_RESDIV\(.+")  
serie_nbrcamvlr = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_NBRCAMVLR\(.+")  
serie_pkmrou = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_PKMROU\(.+")
serie_pkmfertot = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_PKMFERTOT\(.+")
serie_pkm = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_PKM\(.+")
serie_tkm = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_TKM\(.+")
serie_bur = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_BUR\(.+")
serie_bup = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_BUP\(.+")
serie_ectfccc = re.compile("CALC_AGREGAT_PRODUIT\.Calcul_Serie_ECTFCCC\(.+")

serie_co2 = re.compile("CALC_CO2\.Calcul_Serie_CO2\(.+")
co2_eea = re.compile("CALC_CO2\.Calcul_Serie_CO2_EEA\(.+")
elcec = re.compile("CALC_CO2\.Calcul_Serie_ELCEC\(.+")
ectfc = re.compile("CALC_CO2\.Calcul_Serie_ECTFC\(.+")
ectfccc = re.compile("CALC_CO2\.Calcul_Serie_ECTFCCC\(.+")
duplication = re.compile("CALC_CO2\.Duplication_Serie_ODY\(.+")
affectation_rem_div = re.compile("CALC_DATA\.Affectation_Serie_Rem_DIV_UNIT\(.+")

serie_pc = re.compile("CALC_INDICATEURS\.Calcul_Serie_PC\(.+")
ratio = re.compile("CALC_INDICATEURS\.Calcul_Ratio\(.+")
serie_part = re.compile("CALC_INDICATEURS\.Calcul_Serie_Part\(.+")
somme_2series = re.compile("CALC_INDICATEURS\.Somme_2Series_ODY\(.+")
somme_3series = re.compile("CALC_INDICATEURS\.Somme_3Series_ODY\(.+")
diff_2series = re.compile("CALC_INDICATEURS\.Difference_2Series_ODY\(.+")
moy_pond = re.compile("CALC_INDICATEURS\.Calcul_Moy_pond\(.+")
moy_pond_3 = re.compile("CALC_INDICATEURS\.Calcul_Moy_pond_3arg\(.+")
moy_pond_struc_cst = re.compile("CALC_INDICATEURS\.Calcul_Moy_pond_Struc_Cst\(.+")
moy_pond_struc_cst_3 = re.compile("CALC_INDICATEURS\.Calcul_Moy_pond_Struc_Cst_3arg\(.+")
indice100 = re.compile("CALC_INDICATEURS\.Calcul_Serie_Indice100\(.+")
indice100_exp = re.compile("CALC_INDICATEURS\.Calcul_Serie_Indice100_EXP\(.+")
serie_rendement = re.compile("CALC_INDICATEURS\.Calcul_Serie_rendement\(.+")
othcfind = re.compile("CALC_INDICATEURS\.Calcul_OTHCFIND\(.+")
affectation_serie_cste = re.compile("CALC_INDICATEURS\.Affectation_Serie_Cste\(.+")
conversion_coeff = re.compile("CALC_INDICATEURS\.Conversion_coeff\(.+")
conv_courant_ppp = re.compile("CALC_INDICATEURS\.Calcul_Conv_Courant_ppp\(.+")
produit_2series_coeff = re.compile("CALC_INDICATEURS\.Produit_2Series_coeff\(.+")
produit_serie_facteur = re.compile("CALC_INDICATEURS\.Produit_Serie_Facteur\(.+")
produit_anneebase = re.compile("CALC_INDICATEURS\.Calcul_Serie_Produit_AnneeBase\(.+")
serie_cumul = re.compile("CALC_INDICATEURS\.Calcul_Serie_Cumul\(.+")
agregat_secteur_ima = re.compile("CALC_INDICATEURS\.Calcul_Aggregat_Secteur_IMA\(.+")
agregat_secteur_prim = re.compile("CALC_INDICATEURS\.Calcul_Aggregat_Secteurs_Prim\(.+")
serie_aj = re.compile("CALC_INDICATEURS\.Calcul_Serie_AJ\(.+")
hvv_difference = re.compile("CALC_INDICATEURS\.Calcul_Series_HVV_difference\(.+")
serie_cfcc = re.compile("CALC_INDICATEURS\.Calcul_Serie_CFCC\(.+")
ratio_UE = re.compile("CALC_INDICATEURS\.Calcul_Ratio_UE\(.+")
CUEUR = re.compile("CALC_INDICATEURS\.Calcul_Serie_CUEUR\(.+")
CUCC = re.compile("CALC_INDICATEURS\.Calcul_Serie_CUCC\(.+")
CU_EQC = re.compile("CALC_INDICATEURS\.Calcul_Serie_CU_EQC\(.+")
intensite_struc_cst = re.compile("CALC_INDICATEURS.Calcul_Intensite_Struc_Cst\(.+")
VITOC_Branche = re.compile("CALC_INDICATEURS.Calcul_VITOC_Branche\(.+")
VITOC_ED_Secteur = re.compile("CALC_INDICATEURS.Calcul_VITOC_ED_Secteur\(.+")
VITOC_ED = re.compile("CALC_INDICATEURS.Calcul_VITOC_ED\(.+")
series_EEG = re.compile("CALC_INDICATEURS.Calcul_Series_EEG\(.+")
indic_equiv_ch = re.compile("CALC_INDICATEURS.Calcul_Indic_Equiv_Ch\(.+")
VARIETOCXXX = re.compile("CALC_INDICATEURS.Calcul_VARIETOCXXX\(.+")
gdpstruct = re.compile("CALC_INDICATEURS.Calcul_Serie_gdpstruct\(.+")

# La variable ci-dessous permettra de capturer les paramètres de la procédure.

arguments = re.compile("(?<=\().+(?=\))")
ligne_normale = re.compile("CALC_.+")
test_serie = re.compile("(?<=').+(?=')")
arguments2 = re.compile("(?<=IN \().+(?=\))")

# %% [markdown]
# ## Traducteur Odysec

# %%
with open("FichiersSQLTrad/ODYSEC.txt", "r") as odysql, open("FichiersSQLTrad/ODYSEC_traduit.txt", "w") as odypy:

    tot_lignes = 0
    lignes_spe = 0
    non_trad = 0
    nb_erreurs = 0
    cas = 0
    corr_chf = 0

    for ligne in odysql:

        tot_lignes += 1
        bloc_tep = ""

                    
        if ligne[0] in ("-", "/", "S", "I", "E", "*", "D") or re.match("\n", ligne) or re.match("\t\n", ligne):
            odypy.write(ligne)
            lignes_spe += 1

        elif affectation_serie.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            odypy.write(
                "resOdy = affectation(resOdy, {}, {})\n".format(serie, serie_ori))

        elif affectation_serie_mult.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[3]
            coeff = param[2]
            odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids={}, clean=True)\n".format(
                serie, serie, unite, coeff))

        elif affectation_serie_div.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[3]
            coeff = 1/int(param[2])
            odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids={}, clean=True)\n".format(
                serie, serie, unite, coeff))

        elif affectation_serie_ody.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            unite = param[2]
            odypy.write(bloc_tep+"resOdy = affectation(resOdy, {}, {}, {})\n".format(
                serie, serie_ori, unite))

        elif reaffectation_serie_ody.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            serie_ori_rea = param[2]
            unite = param[3]
            odypy.write(bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}], {})\n".format(
                serie, serie_ori, serie_ori_rea, unite))

        elif serie_tkbr.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            coeff = param[2]
            unite = param[3]
            odypy.write("resOdy = affectation(resOdy, {}, {}, 'Gtkb', poids=const.VALEUR[{}])\n".format(
                serie, serie_ori, coeff))

        elif serie_cfferxxx.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            type_transp = serie[9:]
            energie = serie[:4]
            serie_mult1 = energie+"cffer'"
            serie_mult2 = "'tkbfer"+type_transp
            try:
                unite1 = "'"+cOdy[cOdy.serie==serie_mult1[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                try:
                    unite1 = "'"+ed[ed.serie==serie_mult1[1:-1]].unite.iloc[0]+"'"
                except IndexError:
                    odypy.write("ERREUR CFFERXXX SUR "+serie+"\n")
            try:
                unite2 = "'"+cOdy[cOdy.serie==serie_mult2[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                try:
                    unite2 = "'"+ed[ed.serie==serie_mult2[1:-1]].unite.iloc[0]+"'"
                except IndexError:
                    odypy.write("ERREUR CFFERXXX SUR "+serie)
        
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},{}), ({},{})], [('tkbfer','Gtkb')], {})\n".format(
                serie, serie_mult1, unite1, serie_mult2, unite2, unite)) 
        
        elif serie_csvpcxxx.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = "'l/100km'"
            energie = serie[6:9]
            serie_mult = "'cu"+energie+"vpc'"
            unite1 = "'"+cOdy[cOdy.serie==serie_mult[1:-1]].unite.iloc[0]+"'"
            serie_div = "'kmvvpc"+energie+"'"
            unite2 = "'"+ed[ed.serie==serie_div[1:-1]].unite.iloc[0]+"'"
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},{})], [({},{})], {}, poids=10000/(const.VALEUR[{}]*const.VALEUR[{}]))\n".format(
                serie, serie_mult, unite1, serie_div, unite2, unite, "'cst_"+energie+"un'", "'cst_"+energie+"dn'"))
        
        elif serie_cfappels.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            appliance = serie[6:]
            energie = serie[1:4]
            serie_mult1 = "'cs"+energie+appliance
            unite1 = "'"+ed[ed.serie==serie_mult1[1:-1]].unite.iloc[0]+"'"
            serie_mult2 = "'nbr"+appliance
            unite2 = "'"+ed[ed.serie==serie_mult2[1:-1]].unite.iloc[0]+"'"
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},{}), ({},{})], None, {}, poids=0.001)\n".format(
                serie, serie_mult1, unite1, serie_mult2, unite2, unite))

        elif serie_gaz.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write(bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}], {})\n".format(
                "'gaz" + flux, "'gna" + flux, "'gad" + flux, unite))

        elif serie_toc.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write(bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}], {})\n".format(
                "'toc" + flux, "'cmb" + flux, "'elc" + flux, unite))

        elif serie_cmb.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            if flux in ['cfterchf', 'cfterchc']:
                odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{},{},{},{}], {})\n".format(
                    "'cmb" + flux, "'cms" + flux, "'gaz" + flux, "'pet" + flux, "'vap" + flux, "'enc" + flux, "'sol" + flux, unite))
            else:
                odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{},{},{}], {})\n".format(
                    "'cmb" + flux, "'cms" + flux, "'gaz" + flux, "'pet" + flux, "'vap" + flux, "'enc" + flux, unite))

        elif serie_cms.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{},{},{}], {})\n".format(
                "'cms" + flux, "'cha" + flux, "'lig" + flux, "'cok" + flux, "'osf" + flux, "'tou" + flux, unite))

        elif serie_pet.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write(bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{},{},{},{},{},{},{},{}], {})\n".format(
                "'pet" + flux, "'ess" + flux, "'gzl" + flux, "'fol" + flux, "'pdv" + flux, "'gpl" + flux, "'hol" + flux, "'car" + flux, "'esa" + flux, unite))

        elif serie_toccp.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write(bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{},{},{},{},{},'enupd','ehypd','solpd','eeopd','edvpd','eleimex'], {})\n".format(
                "'toc" + flux, "'cms" + flux, "'gaz" + flux, "'pet" + flux, "'enc" + flux, "'oth" + flux, unite))
        
        elif serie_toccfado.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            serie_mult = "'toccfain'"
            unite1 = ed[ed.serie==serie_mult[1:-1]].unite.iloc[0]
            serie_div = "'pcairint'"
            unite2 = ed[ed.serie==serie_div[1:-1]].unite.iloc[0]
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},'{}')], [({},'{}')], {}, poids=1-arr(resOdy[resOdy.serie=='pcairint'].value))\n".format(
            serie, serie_mult, unite1, serie_div, unite2, unite))
        
        elif serie_cicc.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[1:4]
            flux = serie[4:-1]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}], {})\n".format(serie[:-1]+"cc'", serie, "'-"+energie+"cf'", "'"+energie+"cfcc'", unite))
            
        elif serie_csvpcvkm.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            odypy.write("resOdy = multiAffectation(resOdy, {}, ['esscfvpctot','gzlcfvpctot'], {}, poids=100000/(arr(resOdy[resOdy.serie=='nbrvpc'].value)*arr(resOdy[resOdy.serie=='vpcun'].value)*arr(ed[ed.serie=='kmvvpc'].value)))\n".format(serie, unite))
        
        elif serie_vpcun.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]

            odypy.write("resOdy = multiAffectationMultiConv(resOdy, {}, ['esscfvpctot','gzlcfvpctot'], ['Mtoe','Mtoe'], [const.VALEUR['cst_essun']*const.VALEUR['cst_essdn'],const.VALEUR['cst_gzlun']*const.VALEUR['cst_gzldn']], {}, poids=1/(arr(resOdy[resOdy.serie=='gzlcfvpctot'].value)+arr(resOdy[resOdy.serie=='esscfvpctot'].value)))\n".format(
                serie, unite))
 
        elif serie_tep.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_s = serie
            energie = serie[1:4]
            if energie == 'elc':
                serie_s = "'ele"+serie[4:]
            suffixe = serie[4:]
            debut = ""
        
            if (suffixe == 'pd' and serie != 'solpd') or serie == 'eleimex':
                if cas != 1:
                    debut = "\nif pays == 'bel':\n\tc_tep = 0.0001/const.VALEUR['cst_tclun']\nelif pays in ['aut','dnk','esp','fin','fra','grc','irl','ita','nld','nor','prt','rfa']:\n\tc_tep = const.VALEUR['cst_elcun']\nelse:\n\tc_tep = 0.001\n\n"
                cas = 1
            elif serie == "'elecfreslar'":
                if cas != 2:
                    debut = "\nif pays != 'prt':\n\tc_tep = const.VALEUR['cst_elcun']\n"
                cas = 2
            elif serie == "'othcp'":
                if cas != 3:
                    debut = "\nif pays in ['aut', 'bel', 'dnk', 'fin', 'nld', 'rfa','swe']:\n\tc_tep = 0.0001/const.VALEUR['cst_tclun']\nelif pays == 'fra':\n\tc_tep = const.VALEUR['cst_elcun']\nelse:\n\tc_tep = 0.001\n\n"
                cas = 3
            else:
                if cas != 4:
                    debut = "\nif pays in ['aut', 'bel', 'dnk', 'fin', 'nld', 'rfa','swe']:\n\tc_tep = 0.0001/const.VALEUR['cst_tclun']\nelse:\n\tc_tep = 0.001\n\n"
                cas = 4
            odypy.write(debut+"resOdy = affectation(resOdy, {}, {}, 'Mtoe', poids=c_tep, clean=True)\n".format(serie, serie_s))

                        
        elif serie_flvtep.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            energie = serie[1:4]
            try:
                unite_depart = seriesOdy[seriesOdy.serie==serie[1:-1]]["unite"].iloc[0]
            except IndexError:
                try:
                    serie = "'ele"+serie[4:]
                    unite_depart = seriesOdy[seriesOdy.serie == serie[1:-1]]["unite"].iloc[0]
                except IndexError:
                    odypy.write("ERREUR SUR LA SERIE -> "+serie+"\n")
                    nb_erreurs += 1
                    continue
            
            unite_arrivee = "'Mtoe'"
            if unite_depart in ["Gj/t", "GJ/t", "MWh/t"]:
                unite_arrivee = "'toe/t'"
                
            
            serie_bru1 = "'"+energie+"cfflv'"
            serie_bru2 = "'"+energie+"cfmar'"
            if energie == "elc":
                serie_bru1 = "'elecfflv'"
                serie_bru2 = "'elecfmar'"
                
            if unite_depart in ("TJ", "Tj"):
                odypy.write(
                    bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}], {}, poids=1/(const.VALEUR['cst_tclun']*10000))\n".format(
                        serie, serie_bru1, serie_bru2, unite_arrivee))
            elif unite_depart in ("Gj/t", "GJ/t"):
                odypy.write(
                    bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}], {}, poids=1/(const.VALEUR['cst_tclun']*10))\n".format(
                        serie, serie_bru1, serie_bru2, unite_arrivee))
            elif unite_depart == "ktoe":
                odypy.write(
                    bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}], {}, poids=0.001)\n".format(
                        serie, serie_bru1, serie_bru2, unite_arrivee))
            else:
                if unite_depart in ("TWh", "MWh/t"):
                    if energie == "ele":
                        odypy.write(bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}], {}, poids=const.VALEUR['cst_elcun'])\n".format(serie, serie_bru1, serie_bru2, unite_arrivee))
                    else:
                        odypy.write(
                            bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}], {}, poids=const.VALEUR[{}])\n".format(
                                serie, serie_bru1, serie_bru2, unite_arrivee, "'cst_"+energie+"un'"))
                    if unite == 'TWh':
                        odypy.write(
                            bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}], {}, poids=const.VALEUR['cst_elcun'])\n".format(
                                serie, serie_bru1, serie_bru2, unite_arrivee))
                    else:
                        odypy.write(
                            bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}], {}, poids=1000*const.VALEUR['cst_elcun'])\n".format(
                                serie, serie_bru1, serie_bru2, unite_arrivee))
                  
            
                        
        elif serie_cs_tep.search(ligne): #Exception pour la Hongrie (Mm2)
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_bru = param[1]
            serie_sur = param[2] 
            unite_depart = seriesOdy[seriesOdy.serie ==
                serie_bru[1:-1]].unite.iloc[0]
            if unite_depart in ("GJ/dw", "GJ/dwe"):
                odypy.write(
                    "resOdy = affectation(resOdy, {}, {}, 'toe/dw', poids=0.1/(const.VALEUR['cst_tclun']))\n".format(
                        serie, serie_bru))
            
            if unite_depart in ("GJ/m2", "Gj/m2"):
                odypy.write(
                    "resOdy = affectationParMultiplication(resOdy, {}, [({},'GJ/m2'), ({},'m2')], None, 'toe/dw', poids=0.1/const.VALEUR['cst_tclun'])\n".format(
                        serie, serie_bru, serie_sur))
#                     "resOdy = affectation(resOdy, {}, {}, 'toe/dw', poids=arr(ed[ed.serie=={}].value)/const.VALEUR['cst_tclun']/10)\n".format(serie, serie_bru, serie_sur))
            
            if unite_depart in ("MJ/m2", "Mj/m2"):
                odypy.write(
                    "resOdy = affectationParMultiplication(resOdy, {}, [({},'MJ/m2'), ({},'m2')], None, 'toe/dw', poids=0.0001/const.VALEUR['cst_tclun'])\n".format(
                        serie, serie_bru, serie_sur))
#                     "resOdy = affectation(resOdy, {}, {}, 'toe/dw', poids=arr(ed[ed.serie=={}].value)/const.VALEUR['cst_tclun']/10000)\n".format(serie, serie_bru, serie_sur))
            
            if unite_depart == "kWh/m2":
                odypy.write(
                    "resOdy = affectationParMultiplication(resOdy, {}, [({},'kWh/m2'), ({},'m2')], None, 'toe/dw', poids=0.001/const.VALEUR['cst_elcun'])\n".format(
                        serie, serie_bru, serie_sur))
#                     "resOdy = affectation(resOdy, {}, {}, 'toe/dw', poids=arr(ed[ed.serie=={}].value)/const.VALEUR['cst_elcun']/1000)\n".format(serie, serie_bru, serie_sur))
            
            if unite_depart == "kWh/dw":
                odypy.write(
                    "resOdy = affectation(resOdy, {}, {}, 'toe/dw', poids=0.001/(const.VALEUR['cst_elcun']))\n".format(
                        serie, serie_bru))
#                     "resOdy = affectation(resOdy, {}, {}, 'toe/dw', poids=1/const.VALEUR['cst_elcun']/1000)\n".format(serie, serie_bru))

        elif serie_ele.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            odypy.write(
                bloc_tep+"resOdy = affectation(resOdy, {}, {}, 'TWh', poids=1/const.VALEUR['cst_elcun'])\n".format(serie, serie))

        elif serie_cfmpr.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}], {})\n".format(
                serie, energie+"cfsid1'", energie+"cfmnf'", unite))

        elif serie_cfven.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}], {})\n".format(
                serie, energie+"cftra'", energie+"cfind'", energie+"cfret'", unite))

        elif serie_cfretcc.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}], {})\n".format(
                serie, energie+"cfrescc'", energie+"cfdvrcc'", energie+"cfagr'", unite))

        elif serie_cfretce.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}], {})\n".format(
                energie+"cfretce'", energie+"cfresce'", energie+"cfterce'", energie+"cfdvr'", energie+"cfagr'", unite))
            
        elif serie_cfvencc.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}], {})\n".format(
                energie+"cfcc'", energie+"cftra'", energie+"cfind'", energie+"cfretcc'", unite))

        elif serie_cfvence.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}], {})\n".format(
                energie+"cfce'", energie+"cftra'", energie+"cfind'", energie+"cfretce'", unite))
            
        elif serie_cfpas.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            biofuel = serie[-4:]
            if biofuel == "tot'":
                odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}], {})\n".format(
                    energie+"cfpas'", energie+"cfvpctot'", energie+"cfbus'", energie+"cfmot'", energie+"cfferpas'", unite))
            else:
                odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}], {})\n".format(
                    energie+"cfpas'", energie+"cfvpc'", energie+"cfbus'", energie+"cfmot'", energie+"cfferpas'", unite))

        elif serie_cfroudom.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            biofuel = serie[-4:]
            if biofuel == "tot'":
                odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}], {})\n".format(
                    energie+"cfpas'", energie+"cfvpctot'", energie+"cfbus'", energie+"cfmot'", energie+"cfcamvlrtot'", unite))
            else:
                odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}], {})\n".format(
                    energie+"cfpas'", energie+"cfvpc'", energie+"cfbus'", energie+"cfmot'", energie+"cfcamvlr'", unite))
        
        elif serie_cftradom.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, '-esscfvpcfor', '-gzlcfvpcfor', '-gzlcfcamfor'], {})\n".format(serie, energie+"cftra'", unite))
            
        elif serie_ecpas.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}, {}], {})\n".format(
                serie, energie+"ecvpc'", energie+"ecbus'", energie+"ecmot'", energie+"ecferpas'", energie+"ecado'", unite))
        
        elif serie_cfresels1.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[1:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}], {})\n".format(
                serie, "'"+energie+"cfresels'", "'-"+energie+"cfreslgt'", unite))
        
        elif serie_cffermch.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[1:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}], {})\n".format(
                serie, "'"+energie+"cffer'", "'-"+energie+"cfferpas'", unite))
            
        elif serie_cfmch.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}], {})\n".format(
                serie, energie+"cffermch'", energie+"cfflv'", energie+"cfcamvlrtot'", unite))

        elif serie_cfima.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            if energie == "'ele'":
                odypy.write(bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}], {})\n".format(serie, energie+"cfsid1'", energie+"cfmnf'", energie+"cfmnm'",
                            energie+"cfchi'", energie+"cfmac'", energie+"cfiaa'", energie+"cftex'", energie+"cfppp'", energie+"cfidv'", energie+"cfboi'", energie+"cfveh'", energie+"cfwat'", unite))
            else:
                odypy.write(bloc_tep+"resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}], {})\n".format(serie, energie+"cfsid1'", energie+"cfmnf'", energie+"cfmnm'",
                            energie+"cfchi'", energie+"cfmac'", energie+"cfiaa'", energie+"cftex'", energie+"cfppp'", energie+"cfidv'", energie+"cfboi'", energie+"cfveh'", unite))

        elif serie_resdiv.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[1:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}, {}, {}], {})\n".format(
                serie, energie+"cfres'", "'-"+energie+"cfreschf'", "'-"+energie+"cfresecs'", "'-"+energie+"cfrescui'", "'-"+energie+"cfrescli'", "'-"+energie+"cfresels'", unite))

        elif serie_nbrcamvlr.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            parc = serie[:4]
            energie = "'"
            if len(serie) > 10:
                energie = serie[10:]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}], {})\n".format(serie, parc+"cam"+energie, parc+"vlr"+energie, unite))

        elif serie_pkmrou.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            parc = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}], {})\n".format(parc+"rou'", parc+"vpc'", parc+"bus'", unite))

        elif serie_pkmfertot.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            parc = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}], {})\n".format(parc+"fertot'", parc+"fer'", parc+"fermet'", unite))

        elif serie_pkm.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}], {})\n".format(serie, energie+"rou'", energie+"fertot'", energie+"avd'", unite))
            
        elif serie_tkm.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}], {})\n".format(serie, energie+"rou'", energie+"fer'", energie+"flv'", unite))
        
        elif serie_bur.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[1:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{},{},{},{}], {})\n".format(serie, "'"+energie+"ter'", "'-"+energie+"com'", "'-"+energie+"hcr'",  "'-"+energie+"gov'", "'-"+energie+"edu'", "'-"+energie+"hos'", unite))
        
        elif serie_bup.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[1:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{},{},{}], {})\n".format(serie, "'"+energie+"ter'", "'-"+energie+"com'", "'-"+energie+"hcr'", "'-"+energie+"edu'", "'-"+energie+"hos'", unite))
        
        elif serie_Base.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            txchg=param[1]
            unite=param[2]
            an_base=param[4]
            serie_init = serie
            serie_cour=serie[:-3]
            if txchg != "'txchgeuro'":
                serie_cour=serie[:-6]
                serie_init=serie[:-4]+"'"
#             poids="resOdy[(resOdy.serie=={})&(resOdy.year=={})].value.iloc[0]/resOdy[(resOdy.serie=={})&(resOdy.year=={})].value.iloc[0]/resOdy[(resOdy.serie=={})&(resOdy.year=={})].value.iloc[0]".format(
            poids="recupSerie(resOdy,{},{})/recupSerie(resOdy,{},{})/recupSerie(resOdy,{},{})".format(
                serie_cour+"'", an_base, serie_cour+"xx'", an_base, txchg, an_base)
            if ed[(ed.serie==serie_cour[1:])&(ed.year==int(an_base))].empty:
                odypy.write("ERREUR CALCUL_SERIE_BASE sur la série "+serie+"\n")
            else:
                odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids={})\n".format(
                    serie, serie_init, unite, poids))

        elif series_lc.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            txchg=param[1]
            unite=param[2]
            serie_mult = serie
#             try: 
#                 unite1 = "'"+seriesOdy[seriesOdy.serie==serie_mult[1:-1]].unite.iloc[0]+"'"
#             except IndexError:
#                 try:
#                     unite1 = "'"+cOdy[cOdy.serie==serie_mult[1:-1]].unite.iloc[0]+"'"
#                 except IndexError:
#                     odypy.write("ERREUR LC_EURO SUR LA SERIE "+serie_mult+"\n")
#             serie_div = txchg
#             unite2 = "'"+seriesOdy[seriesOdy.serie==serie_div[1:-1]].unite.iloc[0]+"'"
#             if unite != "'MEUR'":
            odypy.write("resOdy = affectationConv(resOdy, {}, {}, {}, '/', {})\n".format(
                serie, serie_mult, serie_div, unite))

#                 odypy.write("resOdy = affectation(resOdy, {}, {}, {}, stop=1998)\nresOdy = affectationParMultiplication(resOdy, {}, [({},{})], [({},{})], {}, start=1999)\n".format(
#                     serie, serie, unite,  serie, serie_mult, unite1, serie_div, unite2, unite))

        elif ratio_base_100.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            an_base=param[2]
#             odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids=100/ed[(ed.serie=={})&(ed.year=={})].value)\n".format(
            odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids=100/recupSerie(resOdy,{},{}))\n".format(
                serie, serie, unite, serie, an_base))

        elif corr_clim.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            if serie[1:4] == 'elc':
                serie = "'ele"+serie[4:]
            part_chauff=param[1]
            unite=param[2]
            odypy.write("resOdy = correctionClimatique(resOdy, {}, {}, {})\n".format(
                serie, part_chauff, unite))
#         poids=1/(1-arr(ed[ed.serie=={}].value)*0.9*(1-arr(ed[ed.serie=='dj'].value)/arr(ed[ed.serie=='djref'].value))

        elif corr_clim_chf.search(ligne):
            debut = ""
            if corr_chf == 0:
                debut = "corr_clim_chf = 1/(1-0.9*(1-arr(ed[ed.serie=='dj'].value)/arr(ed[ed.serie=='djref'].value)))\n"
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            odypy.write(
                debut+"resOdy = affectation(resOdy, {}, {}, {}, poids={})\n".format(
                    serie[:-4]+"chc'", serie, unite, "corr_clim_chf"))
            corr_chf += 1
#         1/(1-0.9*(1-arr(ed[ed.serie=='dj'].value)/arr(ed[ed.serie=='djref'].value)))
            
        elif corr_clim_ce.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            pays_aj=param[3]
            energie = serie[1:4]
            secteur = serie[6:9]
            part_chauff = "'pcchf"+energie+secteur+"cc'"
            if ed[ed.serie==part_chauff[1:-1]].empty:
                part_chauff = "'pcchf"+secteur+"cc'"
            odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids=(1-arr(ed[ed.serie=={}].value)*(arr(eurdata[eurdata.serie=='djrefcomp'].value)/arr(ed[ed.serie=='djrefcomp'].value)-1)))\n".format(
                serie[:-1]+"ce'", serie[:-1]+"cc'", unite, part_chauff))
            
        elif serie_pc.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            serie_tot=param[2]
            unite=param[3]
            try:
                unite1 = "'"+ed[ed.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                try:
                    unite1 = "'"+cOdy[cOdy.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
                except IndexError:
                    odypy.write("ERREUR SERIE_PC "+serie)
            try:
                unite2 = "'"+ed[ed.serie==serie_tot[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                unite2 = "'"+cOdy[cOdy.serie==serie_tot[1:-1]].unite.iloc[0]+"'"
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},{})], [({},{})], {}, poids=100)\n".format(
                serie, serie_ori, unite1, serie_tot, unite2, unite))

        elif ratio.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            serie_tot=param[2]
            unite=param[3]
            unite1 = "'"+cOdy[cOdy.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
            unite2 = "'"+cOdy[cOdy.serie==serie_tot[1:-1]].unite.iloc[0]+"'"
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},{})], [({},{})], {})\n".format(
                serie, serie_ori, unite1, serie_tot, unite2, unite))

        elif serie_part.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            serie_tot=param[2]
            N=param[3]
            unite=param[4]
            try:
                unite1 = "'"+ed[ed.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                unite1 = "'"+cOdy[cOdy.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
            try:
                unite2 = "'"+ed[ed.serie==serie_tot[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                unite2 = "'"+cOdy[cOdy.serie==serie_tot[1:-1]].unite.iloc[0]+"'"
            odypy.write(bloc_tep+"resOdy = affectationParMultiplication(resOdy, {}, [({},{})], [({},{})], {}, poids={})\n".format(
                serie, serie_ori, unite1, serie_tot, unite2, unite, N))
            
            
        elif somme_2series.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie1=param[1]
            serie2=param[2]
            unite = param[3]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{}], {})\n".format(serie, serie1, serie2, unite))
        
        elif somme_3series.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie1=param[1]
            serie2=param[2]
            serie3=param[3]
            unite = param[4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{}], {})\n".format(serie, serie1, serie2, serie3, unite))
            
        elif diff_2series.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie1=param[1]
            serie2=param[2]
            unite = param[3]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{}], {})\n".format(serie, serie1, "'-"+serie2[1:], unite))
        
        elif moy_pond.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_num1=param[1]
#             unite_num1=resOdy[resOdy.serie==serie_num1[1:-1]].unite.iloc[-1]
            serie_num2=param[2]
#             unite_num2=resOdy[resOdy.serie==serie_num2[1:-1]].unite.iloc[-1]
            serie_den1=param[3]
#             unite_den1=resOdy[resOdy.serie==serie_den1[1:-1]].unite.iloc[-1]
            serie_den2=param[4]
#             unite_den2=resOdy[resOdy.serie==serie_den2[1:-1]].unite.iloc[-1]
            unite=param[5]
            pays_ref=param[6]
            odypy.write("resOdy = MoyennePond(resOdy, {}, [{},{}], [1.0,1.0], [{},{}], {})\n".format(serie, serie_num1, serie_num2, serie_den1, serie_den2, unite))
        
        else:
            odypy.write(ligne)
            if re.search("CALC", ligne):
                non_trad += 1
        
        prev_line = ligne

print("Nb de lignes :", tot_lignes)
print("Lignes à vérifier (conditions et commentaires) :", lignes_spe)
print("Reste à traduire :", non_trad)
print("Nombre d'erreurs :", nb_erreurs)

# %% [markdown]
# ## Traducteur OdyCO2

# %%
with open("FichiersSQLTrad/ODYCO2.txt", "r") as odysql, open("FichiersSQLTrad/ODYCO2_traduit.txt", "w") as odypy:
    
    tot_lignes = 0
    lignes_spe = 0
    non_trad = 0

    for ligne in odysql:
        
        tot_lignes += 1
        
        if ligne[0] in ("-", "/", "S", "I", "E", "*"):
            odypy.write(ligne)
            lignes_spe += 1

#Data

        elif affectation_serie.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            if serie_ori == serie:
                odypy.write("resOdy = affectation(resOdy, {}, {}, clean=True)\n".format(
                    serie, serie_ori))
            else:
                odypy.write("resOdy = affectation(resOdy, {}, {})\n".format(
                    serie, serie_ori))
            
        elif affectation_serie_ody.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            unite = param[2]
            odypy.write("resOdy = affectation(resOdy, {}, {}, {})\n".format(
                serie, serie_ori, unite))
            
        elif affectation_rem_div.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            coeff = 1/int(param[3])
            unite_calc = param[4]
            odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids={}, clean=True)\n".format(
                serie, serie_ori, unite_calc, str(coeff)))

#Agregat_Energie  
        
        elif reaffectation_serie_ody.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            serie_ori_rea = param[2]
            unite = param[3]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{}], {})\n".format(
                serie, serie_ori, serie_ori_rea, unite))
            
        elif serie_gaz.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{}], {})\n".format(
                "'gaz" + flux, "'gna" + flux, "'gad" + flux, unite))
            
        elif serie_cms.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{},{},{}], {})\n".format(
                "'cms" + flux, "'cha" + flux, "'lig" + flux, "'cok" + flux, "'osf" + flux, "'tou" + flux, unite))

        elif serie_pet.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{},{},{},{},{},{}], {})\n".format(
                "'pet" + flux, "'ess" + flux, "'gzl" + flux, "'fol" + flux, "'pdv" + flux, "'gpl" + flux, "'hol" + flux, "'car" + flux, "'esa" + flux, unite))
        
        elif serie_cmbec.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{}], {})\n".format(
                "'cmb" + flux, "'cms" + flux, "'gaz" + flux, "'pet" + flux, unite))
            
        elif serie_cmbec_eea.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[6:]
            sect = serie[6:9]+"'"
            sect2 = sect
            if flux == "totcc'":
                flux = "cc'"
                sect = "cmb'"
                sect2 = "'"
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},'MtCO2'),({},'Mtoe')], [({},'Mtoe')], {}, serieOblig=[{},{}])\n".format(
                serie, "'co2"+sect, "'cmbcf"+flux, "'cmbcf"+sect2, unite, "'co2"+sect, "'cmbcf"+flux))
            
        elif serie_cmbecind.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{},'cmbecieao'], {})\n".format(
                "'cmb" + flux, "'cms" + flux, "'gaz" + flux, "'pet" + flux, unite))
            
        elif serie_ectot.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:6]
            cclim = serie[9:11]
            if cclim[-1] != "'":
                cclim+="'"
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{}], {})\n".format(
                "'cmb"+flux+"tot"+cclim, "'tce"+flux+"tfc"+cclim, "'cmb"+flux+"otr"+cclim, unite))
            
        elif serie_tceec.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            flux = serie[4:]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{}], {})\n".format(
                "'tce" + flux, "'cmb" + flux, "'elc" + flux, "'vap" + flux, unite))   
            
# Agregat_Produit           
            
        elif serie_ecpas.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}, {}], {})\n".format(
                serie, energie+"ecvpc'", energie+"ecbus'", energie+"ecmot'", energie+"ecferpas'", energie+"ecado'", unite))

        elif serie_ectfccc.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{}], {})\n".format(
                energie+"ectfccc'", energie+"ectra'", energie+"ecind'", energie+"ecretcc'", unite))
            
#CO2
    
        elif serie_co2.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            s_tep = param[1]
            coeff = param[2]
            unite = param[3]
            typ_coeff = coeff[1:5]
            if serie == "'carecair'":
#                 odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},'Mtoe'),('pcairint','1')], None, {}, poids=const.VALEUR[{}])\n".format(
                odypy.write("resOdy = affectationConv(resOdy, {}, {}, 'pcairint', '*', 'MtCO2', poids=const.VALEUR[{}])\n".format(
                    serie, s_tep, coeff))
            else:
                if typ_coeff == "cst_":
                    odypy.write("resOdy = affectation(resOdy, {}, {}, 'MtCO2', poids=const.VALEUR[{}])\n".format(
                        serie, s_tep, coeff))
                    
                else:
#                     odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},'Mtoe'),({},'tCO2/toe')], None, {})\n".format(
                    odypy.write("resOdy = affectationConv(resOdy, {}, {}, {}, '*', 'MtCO2')\n".format(
                        serie, s_tep, coeff))
                
        elif co2_eea.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            s_tep = param[1]
            coeff = param[2]
            unite = param[3]
            typ_coeff = coeff[1:5]
            if typ_coeff == "cst_":
                odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [('co2rou','MtCO2'),({},'Mtoe')], [('cmbecroudom','MtCO2')], 'MtCO2', poids=const.VALEUR[{}], serieOblig=[{}])\n".format(
                    serie, s_tep, coeff, s_tep))
            else:
                odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [('co2rou','MtCO2'),({},'Mtoe'),({},'tCO2/toe')], [('cmbecroudom','MtCO2')], 'MtCO2', serieOblig=[{}])\n".format(
                    serie, s_tep, coeff, s_tep))
              
        elif ectfc.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{}], {})\n".format(
                energie+"ectfc'", energie+"ectra'", energie+"ecind'", energie+"ecret'", unite)) 
        
        elif ectfccc.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            energie = serie[:4]
#             odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},'MtCO2'),('cmbcfcc','Mtoe')], [('cmbcf','Mtoe')], {})\n".format(
#                 energie+"ectfccc'", energie+"ectfc'", unite))
#             Différence equation théorique et équation réelle ('xxxectfccc'='xxxectfc')
            odypy.write("resOdy = affectation(resOdy, {}, {})\n".format(energie+"ectfccc'", energie+"ectfc'"))
            
        elif elcec.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            s_tep = param[1]
            coeff = param[2]
            unite = param[3]
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},'Mtoe'),({},'tCO2/toe'),('elepd','TWh')], [('eleci','TWh')], 'MtCO2')\n".format(
                        serie, s_tep, coeff))
        
        elif duplication.search(ligne): 
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            odypy.write("resOdy = CompletionSerie(resOdy, {}, 'ffill')\n".format(
                serie))
    
# Indicateurs
            
        elif ratio.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            serie_tot=param[2]
            unite=param[3]
            unite1 = "'"+seriesOdyC[seriesOdyC.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
            unite2 = "'"+seriesOdyC[seriesOdyC.serie==serie_tot[1:-1]].unite.iloc[0]+"'"
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},{})], [({},{})], {})\n".format(
                serie, serie_ori, unite1, serie_tot, unite2, unite))

        elif somme_2series.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie1=param[1]
            serie2=param[2]
            unite = param[3]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{}], {})\n".format(serie, serie1, serie2, unite))

        elif diff_2series.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie1=param[1]
            serie2=param[2]
            unite = param[3]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{}], {})\n".format(serie, serie1, "'-"+serie2[1:], unite))

        else:
            odypy.write("\n")
            if re.search("CALC", ligne):
                non_trad += 1
                
print("Nb de lignes :", tot_lignes)
print("Lignes à vérifier (conditions et commentaires) :", lignes_spe)
print("Reste à traduire :", non_trad)

# %% [markdown]
# ## Traducteur IndicOdy

# %%
with open("FichiersSQLTrad/INDICODY.txt", "r") as odysql, open("FichiersSQLTrad/INDICODY_traduit.txt", "w") as odypy, open("FichiersSQLTrad/INDICODY_reste.txt", "w") as odyreste:
    
    tot_lignes = 0
    lignes_spe = 0
    non_trad = 0
    cas = 0
    compt_cueur = 0
    compt_equiv = 0
    compt_ppp = 0
    l_suppr = []

    for ligne in odysql:
        
        tot_lignes += 1
        
        if ligne_normale.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            if not serie[1:-1] in seriesOdyC.values:
                odyreste.write(ligne)
                continue
            else:
                pass
            
        if ligne[0] in ("-", "/", "S", "I", "E", "*"):
            odypy.write(ligne)
            lignes_spe += 1





# Data


        elif affectation_serie.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            odypy.write("resOdy = affectation(resOdy, {}, {})\n".format(
                serie, serie_ori))
            
        elif serie_tep.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            energie = serie[1:4]
            serie_s = serie
            if energie == 'elc':
                serie_s = "'ele"+serie[4:]
            suffixe = serie[4:]
            debut = ""
        
            if (suffixe == 'pd' and serie != 'solpd') or serie == 'eleimex':
                if cas != 1:
                    debut = "\nif pays == 'bel':\n\tc_tep = 0.0001/const.VALEUR['cst_tclun']\nelif pays in ['aut','dnk','esp','fin','fra','grc','irl','ita','nld','nor','prt','rfa']:\n\tc_tep = const.VALEUR['cst_elcun']\nelse:\n\tc_tep = 0.001\n\n"
                cas = 1
            elif serie == "'elecfreslar'":
                if cas != 2:
                    debut = "\nif pays != 'prt':\n\tc_tep = const.VALEUR['cst_elcun']\n"
                cas = 2
            elif serie == "'othcp'":
                if cas != 3:
                    debut = "\nif pays in ['aut', 'bel', 'dnk', 'fin', 'nld', 'rfa','swe']:\n\tc_tep = 0.0001/const.VALEUR['cst_tclun']\nelif pays == 'fra':\n\tc_tep = const.VALEUR['cst_elcun']\nelse:\n\tc_tep = 0.001\n\n"
                cas = 3
            else:
                if cas != 4:
                    debut = "\nif pays in ['aut', 'bel', 'dnk', 'fin', 'nld', 'rfa','swe']:\n\tc_tep = 0.0001/const.VALEUR['cst_tclun']\nelse:\n\tc_tep = 0.001\n\n"
                cas = 4
            odypy.write(debut+"resOdy = affectation(resOdy, {}, {}, 'Mtoe', poids=c_tep, clean=True)\n".format(serie, serie_s))

        elif serie_ele.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_s = serie
            if serie[1:4] == 'ele':
                serie_s = "'elc"+serie[4:]
            odypy.write(
                "resOdy = affectation(resOdy, {}, {}, 'TWh', poids=1/const.VALEUR['cst_elcun'])\n".format(serie, serie_s))

        elif serie_csvpcth.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            unite = param[1]
            odypy.write("resOdy = calculCSVPCTH(resOdy, {}, {})\n".format(
                serie, unite))


# Eco

        elif serie_Base.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            txchg=param[1]
            unite=param[2]
            an_base=param[4]
            serie_init = serie
            serie_cour=serie[:-3]
            if txchg != "'txchgeuro'":
                serie_cour=serie[:-6]
                serie_init=serie[:-4]+"'"
            poids="recupSerie(resOdy,{},{})/recupSerie(resOdy,{},{})/recupSerie(resOdy,{},{})".format(
                serie_cour+"'", an_base, serie_cour+"xx'", an_base, txchg, an_base)
#             if ed[(ed.serie==serie_cour[1:])&(ed.year==int(an_base))].empty:
#                 odypy.write("ERREUR CALCUL_SERIE_BASE sur la série "+serie+"\n")
#             else:
            odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids={})\n".format(
                serie, serie_init, unite, poids))
            

# Agregat_Energie  


        elif affectation_serie_ody.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            unite = param[2]
            odypy.write("resOdy = affectation(resOdy, {}, {}, {})\n".format(
                serie, serie_ori, unite))
            



# Indicateurs


    #Affectations et conversions
    
        elif affectation_serie_cste.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            cste = param[1]
            unite = param[2]
            odypy.write("resOdy = CompletionSerie(resOdy, {}, 'fill', {})\n".format(
                serie, cste))
            
        elif conversion_coeff.search(ligne):
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            cste = param[2]
            coeff = param[3]
            unite = param[5]
            odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids={}*const.VALEUR[{}])\n".format(
                serie, serie_ori, unite, coeff, cste))
            
        elif conv_courant_ppp.search(ligne):
            compt_ppp += 1
            param = arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            unite = param[2]
            debut = "coeff_ppp = recupSerie(resOdy,'pibxx',2010)/recupSerie(resOdy,'pib',2010)*(recupSerie(resOdy,'txchgppp',2010)/recupSerie(resOdy,'txchgeuro',2010))\n"
            if compt_ppp == 1:
                odypy.write(debut+"resOdy = affectation(resOdy, {}, {}, {}, poids=coeff_ppp)\n".format(
                    serie, serie_ori, unite))
            else:
                odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids=coeff_ppp)\n".format(
                    serie, serie_ori, unite))


    #Sommes et produits
    
        elif somme_2series.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie1=param[1]
            serie2=param[2]
            unite = param[3]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{}], {})\n".format(serie, serie1, serie2, unite))

        elif somme_3series.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie1=param[1]
            serie2=param[2]
            serie3=param[3]
            unite = param[4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{},{}], {})\n".format(serie, serie1, serie2, serie3, unite))

        elif diff_2series.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie1=param[1]
            serie2=param[2]
            unite = param[3]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{},{}], {})\n".format(serie, serie1, "'-"+serie2[1:], unite))
        
        elif produit_2series_coeff.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie1=param[1]
            serie2=param[2]
            nb=param[3]
            unite = param[4]
            try:
                unite1 = "'"+seriesOdyC[seriesOdyC.serie==serie1[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                try:
                    unite1 = "'"+seriesOdyS[seriesOdyS.serie==serie1[1:-1]].unite.iloc[0]+"'"
                except IndexError:
                    odyreste.write(ligne)
                    continue
            try:
                unite2 = "'"+seriesOdyC[seriesOdyC.serie==serie2[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                try:
                    unite2 = "'"+seriesOdyS[seriesOdyS.serie==serie2[1:-1]].unite.iloc[0]+"'"
                except IndexError:
                    odyreste.write(ligne)
                    continue
            if nb[:3]=='cst' and nb[4:]!='travail':
                odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},{}),({},{})], None, {}, poids=const.VALEUR['{}'])\n".format(
                    serie, serie1, unite1, serie2, unite2, unite, nb))
            else:
                odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},{}),({},{})], None, {}, poids={})\n".format(
                    serie, serie1, unite1, serie2, unite2, unite, nb))
                
        elif produit_serie_facteur.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            nb=param[2]
            unite = param[3]
#             try:
#                 unite_s = "'"+seriesOdyC[seriesOdyC.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
#             except IndexError:
#                 try:
#                     unite_s = "'"+seriesOdyS[seriesOdyS.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
#                 except IndexError:
#                     odyreste.write(ligne)
#                     continue
            if nb[:4]== 'cst_' and nb[4:]!='travail':
                odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids=const.VALEUR['{}'])\n".format(
                    serie, serie_ori, unite, nb))
            else:
                odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids={})\n".format(
                    serie, serie_ori, unite, nb))
                
        elif produit_anneebase.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie = param[0]
            serie_ori = param[1]
            serie_base = param[2]
            coeff = param[3]
            unite = param[4]
            odypy.write("resOdy = affectation(resOdy, {}, {}, {}, poids={}*recupSerie(resOdy,{},2000))\n".format(
                serie, serie_ori, unite, coeff, serie_base))
            
        elif serie_cumul.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            suf=serie[-3:-1]
            pre=serie[1:4]
            if suf=='to':
                serie_cum=serie[:-3]
            if suf=='um':
                serie_cum=serie[:-4]
            if suf in ['m1', 'm3', 'm4']:
                serie_cum=serie[:-5]
            if pre=='sav':
                signe='-'
            else:
                signe='+'
            if suf=='m4':
                serie_cum = serie_cum[:-1]+"cum3"
                signe='+'
#             if signe == '-':
#                 odypy.write("resOdy = totalCumul(resOdy, {}, {}, {}, poids=-1)\n".format(
#                     serie, serie_cum+"'", unite))
#             else:
            odypy.write("resOdy = totalCumul(resOdy, {}, {}, {})\n".format(
                serie, serie_cum+"'", unite))


    #Moyennes
    
        elif moy_pond.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_num1=param[1]
            serie_num2=param[2]
            serie_den1=param[3]
            serie_den2=param[4]
            unite=param[5]
            pays_ref = param[6]
            if pays_ref == "'ueur'":
                u1 = "'"+UEdata[UEdata.serie==serie_den1[1:-1]].unite.iloc[0]+"'"
                odypy.write("resOdy = transfert(resOdy, UEdata, [({},{}), ({},{})], 'UE')\n".format(
                    serie_den1, u1, serie_den2, u1) +
                "resOdy = MoyennePond(resOdy, {}, [{},{}], [1.0,1.0,1.0], [{},{}], {})\n".format(
                    serie, serie_num1, serie_num2, serie_den1[:-1]+"_UE'", serie_den2[:-1]+"_UE'", unite))
            else:
                odypy.write("resOdy = MoyennePond(resOdy, {}, [{},{}], [1.0,1.0], [{},{}], {})\n".format(serie, serie_num1, serie_num2, serie_den1, serie_den2, unite))
            
        elif moy_pond_3.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_num1=param[1]
            serie_num2=param[2]
            serie_num3=param[3]
            serie_den1=param[4]
            serie_den2=param[5]
            serie_den3=param[6]
            unite=param[7]
            pays_ref = param[8]
            if pays_ref == "'ueur'":
                u1 = "'"+UEdata[UEdata.serie==serie_den1[1:-1]].unite.iloc[0]+"'"
                odypy.write("resOdy = transfert(resOdy, UEdata, [({},{}), ({},{}), ({},{})], 'UE')\n".format(
                    serie_den1, u1, serie_den2, u1, serie_den3, u1) +
                "resOdy = MoyennePond(resOdy, {}, [{},{},{}], [1.0,1.0,1.0], [{},{},{}], {})\n".format(
                    serie, serie_num1, serie_num2, serie_num3, serie_den1[:-1]+"_UE'", serie_den2[:-1]+"_UE'", serie_den3[:-1]+"_UE'", unite))
                
            else:
                odypy.write("resOdy = MoyennePond(resOdy, {}, [{},{},{}], [1.0,1.0,1.0], [{},{},{}], {})\n".format(
                    serie, serie_num1, serie_num2, serie_num3, serie_den1, serie_den2, serie_den3, unite))

        elif moy_pond_struc_cst.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_num1=param[1]
            serie_num2=param[2]
            serie_den1=param[3]
            serie_den2=param[4]
            unite=param[5]
            an_base=2000
            odypy.write("resOdy = MoyennePondStruCste(resOdy, {}, [{},{}], [{},{}], {}, {})\n".format(
                serie, serie_num1, serie_num2, serie_den1, serie_den2, an_base, unite))
            
        elif moy_pond_struc_cst_3.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie=param[0]
            serie_num1=param[1]
            serie_num2=param[2]
            serie_num3=param[3]
            serie_den1=param[4]
            serie_den2=param[5]
            serie_den3=param[6]
            unite=param[7]
            an_base=2000
            odypy.write("resOdy = MoyennePondStruCste(resOdy, {}, [{},{},{}], [{},{},{}], {}, {})\n".format(
                serie, serie_num1, serie_num2, serie_num3, serie_den1, serie_den2, serie_den3, an_base, unite))


    #Agrégats
        
        elif agregat_secteur_ima.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            serie_pre=serie[:9]
            diver_ind='idv'
            if serie[1:6]=='vitoc':
                diver_ind='dvi'
            if serie_pre[1:]=='toccfima':
                serie_pre="'toccf"
            if serie_pre[1:]=='vadimaxx':
                serie_pre="'vad"
            serie_suf=serie[-3:]
            if serie[-4:-1]=='xx1':
                serie_suf="xx'"
            if not serie_suf[:-1] in ['sd', 'ed', 'aj', 'xx']:
                serie_suf="'"
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}], {})\n".format(
                serie, serie_pre+'mpr'+serie_suf, 
                serie_pre+'chi'+serie_suf, 
                serie_pre+'ppp'+serie_suf, 
                serie_pre+'mnm'+serie_suf, 
                serie_pre+'iaa'+serie_suf, 
                serie_pre+'mac'+serie_suf, 
                serie_pre+'veh'+serie_suf, 
                serie_pre+'tex'+serie_suf, 
                serie_pre+diver_ind+serie_suf, 
                serie_pre+'boi'+serie_suf, 
                serie_pre+'wat'+serie_suf, unite))
            
        elif agregat_secteur_prim.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            serie_pre=serie[:9]
            serie_suf=serie[-3:]
            serie_suf1=serie[-5:-3]
            if serie_pre=="'vitoccfc":
                serie_pre="'vitocpib"
            if serie_suf1=='ce':
                serie_suf1=serie_suf1+serie_suf
            else:
                serie_suf1=serie_suf
            if serie=="'savfinairexc'":
                serie_pre="'sav"
                serie_suf="'"
                serie_suf="'"
            if serie_suf1[-1]!="'":
                serie_suf1+="'"
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}, {}, {}], {})\n".format(
                serie, serie_pre+'inde'+serie_suf, 
                serie_pre+'ind'+serie_suf, 
                serie_pre+'res'+serie_suf1, 
                serie_pre+'dvr'+serie_suf1, 
                serie_pre+'tra'+serie_suf, 
                serie_pre+'agr'+serie_suf, unite))
                        
        
    #Ratios, pourcentages, indices
    
        elif ratio.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            serie_tot=param[2]
            unite=param[3]
            try:
                unite1 = "'"+seriesOdyC[seriesOdyC.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                try:
                    unite1 = "'"+seriesOdyS[seriesOdyS.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
                except IndexError:
                    odyreste.write(ligne)
                    continue
            try:
                unite2 = "'"+seriesOdyC[seriesOdyC.serie==serie_tot[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                try:
                    unite2 = "'"+seriesOdyS[seriesOdyS.serie==serie_tot[1:-1]].unite.iloc[0]+"'"
                except IndexError:
                    odyreste.write(ligne)
                    continue
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},{})], [({},{})], {})\n".format(
                serie, serie_ori, unite1, serie_tot, unite2, unite))
            
        elif ratio_UE.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            unite=param[2]
            odypy.write("resOdy = transfert(resOdy, UEdata, [({},'degree')], 'UE')\n".format(serie_ori)+
                        "resOdy = affectationParMultiplication(resOdy, {}, [({},'degree')], [({},'degree')], {})\n".format(
                            serie, serie_ori[:-1]+"_UE'", serie_ori, unite))
            l_suppr.append(serie_ori[1:-1]+"_UE")
                            
        elif serie_part.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            serie_tot=param[2]
            N=param[3]
            unite=param[4]
            try:
                unite1 = "'"+seriesOdyC[seriesOdyC.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                try:
                    unite1 = "'"+seriesOdyS[seriesOdyS.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
                except IndexError:
                    odyreste.write(ligne)
                    continue
            try:
                unite2 = "'"+seriesOdyC[seriesOdyC.serie==serie_tot[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                try:
                    unite2 = "'"+seriesOdyS[seriesOdyS.serie==serie_tot[1:-1]].unite.iloc[0]+"'"
                except IndexError:
                    odyreste.write(ligne)
                    continue
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, [({},{})], [({},{})], {}, poids={})\n".format(
                serie, serie_ori, unite1, serie_tot, unite2, unite, N))    
            
        elif serie_rendement.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            unite=param[2]
            odypy.write("resOdy = affectationParMultiplication(resOdy, {}, None, [({},{})], '%', poids=100)\n".format(
                serie, serie_ori, unite))
            
        elif indice100.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie_r = param[0]
            date_base = param[1]
            if date_base == "v_an_base":
                date_base = 2000
            serie_s = "'"+serie_r[2:]
            odypy.write("resOdy = affectation(resOdy, {}, {}, '{}=100', poids=100/recupSerie(resOdy,{},{}))\n".format(
                serie_r, serie_s, date_base, serie_s, date_base))
            
        elif indice100_exp.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie_r = param[0]
            date_base = param[1]
            if date_base == "v_an_base":
                date_base = 2000
            tocimaxx = serie_r[3:-1]
            serie_s = "'vi"+tocimaxx+"to'"
            odypy.write("resOdy = affectation(resOdy, {}, {}, '{}=100', formule=lambda x : np.exp(x-recupSerie(resOdy,{},{}))*100)\n".format(
                serie_r, serie_s, date_base, serie_s, date_base))

    #Consommations unitaires
    
        elif CUEUR.search(ligne):
            compt_cueur += 1
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            usage_fin=serie[-4:]
            den=serie[6:9]
            if den=='log':
                serie_den="'nbrlpr'"
                unite_den="'k'"
            if den=='sur':
                serie_den="'surres'"
                unite_den="'Mm2'"
            if compt_cueur == 1: 
                debut="lcoeff = list(const.VALEUR[['cst_cmsrend', 'cst_petrend', 'cst_gazrend', 'cst_encrend', 'cst_vaprend', 'cst_elerend']])\n"
            else:
                debut=""
            odypy.write(debut+"resOdy = multiAffectationMultiConv(resOdy, {}, [{},{},{},{},{},{}], ['Mtoe'], lcoeff, None)\nresOdy = affectationParMultiplication(resOdy, {}, [({},None)], [({},{})], {}, poids=10)\n".format(
                            serie[:-1]+"_prov'", "'cmscfres"+usage_fin, "'petcfres"+usage_fin, "'gazcfres"+usage_fin,
                            "'enccfres"+usage_fin, "'vapcfres"+usage_fin, "'elccfres"+usage_fin, 
                            serie, serie[:-1]+"_prov'", serie_den, unite_den, unite))
            l_suppr.append(serie[1:-1]+"_prov")
        
        elif CUCC.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            unite=param[2]
            odypy.write("resOdy = calculCUCC(resOdy, {}, {}, {})\n".format(
                serie, serie_ori, unite))
            
        elif CU_EQC.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            if serie=="'cuesseqc'":
                odypy.write("l_coeff = [1]+list(const.VALEUR[['cst_coefvpcmot','cst_coefvpcbus','cst_coefvpccamvlre']])\n"
                            +"resOdy = multiAffectationMultiConv(resOdy, 'coeff_cuesseqc', ['nbrvpcess','nbrmot','nbrbusess','nbrcamvlress'], ['M'], l_coeff, None)\n"
                            +"resOdy = affectationConv(resOdy, 'cuesseqc', 'esscfroudom', 'coeff_cuesseqc', '/', 'toe/careq')\n")
            if serie=="'cutoceqc'":
                odypy.write("l_coeff = [1]+list(const.VALEUR[['cst_coefvpcmot','cst_coefvpcbus','cst_coefvpccamvlr']])\n"
                            +"resOdy = multiAffectationMultiConv(resOdy, 'coeff_cutoceqc', ['nbrvpc','nbrmot','nbrbus','nbrcamvlr'], ['M'], l_coeff, None)\n"
                            +"resOdy = affectationConv(resOdy, 'cutoceqc', 'toccfroudom', 'coeff_cutoceqc', '/', 'toe/careq')\n")
            l_suppr += ['coeff_cuesseqc', 'coeff_cutoceqc']
            
        elif indic_equiv_ch.search(ligne):
            compt_equiv+=1
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            unite=param[2]
            debut=""
            if compt_equiv == 1:
                debut="resOdy = affectation(resOdy, 'coeff_equivChf', 'pcdwchc', formule=lambda x : x+((1-x)*0.75))\n"
            odypy.write(debut+"resOdy = affectationConv(resOdy, {}, {}, 'coeff_equivChf', '/', {})\n".format(
                serie, serie_ori, unite))
            l_suppr.append('coeff_equivChf')
            

    #Séries particulières
    
        elif serie_aj.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            serie_ue1=param[2]
            serie_ue2=param[3]
            unite=param[4]
            try:
                unite_ori = "'"+seriesOdyC[seriesOdyC.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                    unite_ori = "'"+seriesOdyS[seriesOdyS.serie==serie_ori[1:-1]].unite.iloc[0]+"'"
            try:
                unite_ue1 = "'"+UEdata[UEdata.serie==serie_ue1[1:-1]].unite.iloc[0]+"'"
                unite_ue2 = "'"+UEdata[UEdata.serie==serie_ue2[1:-1]].unite.iloc[0]+"'"
            except IndexError:
                odypy.write("Erreur calcul {} sur l'une des séries UE: {}, {}\n".format(serie, serie_ue1, serie_ue2))
                continue
            odypy.write("resOdy = transfert(resOdy, UEdata, [({},{}),({},{})], 'UE')\nresOdy = affectationParMultiplication(resOdy, {}, [({},{}), ({},{})], [({},{})], {})\n".format(
                serie_ue1, unite_ue1, serie_ue2, unite_ue2, 
                serie, serie_ori, unite_ori, serie_ue1[:-1]+"_UE'", unite_ue1, serie_ue2[:-1]+"_UE'", unite_ue2, unite))
            l_suppr += [serie_ue1[1:-1]+"_UE", serie_ue2[1:-1]+"_UE"]
          
        elif hvv_difference.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            energie=serie[1:4]
            odypy.write("resOdy = multiAffectation(resOdy, {}, [{}, {}, {}, {}], {})\n".format(
                serie, "'"+energie+"cfrou'", 
                "'-"+energie+"cfvpctot'", "'-"+energie+"cfvlr'", "'-"+energie+"cfmot'", unite))
        
        elif serie_cfcc.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie_ori=param[1]
            unite=param[2]
            odypy.write("resOdy = correctionClimatiqueChf(resOdy, {}, {})\n".format(
                serie, unite))
        
        elif VARIETOCXXX.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie_ori=param[0]
            date_base=2000
            flux=serie[-4:]
            if flux=='tcf':
                flux='cf'
            if flux=='tpc':
                flux='cp'
            serieR="'varietoc"+flux
            odypy.write("resOdy = affectation(resOdy, {}, {}, '1', formule=lambda x:1+(x-recupSerie(resOdy,{},2000))/recupSerie(resOdy,'ietoctpc',2000))\n".format(
                serieR, serie_ori, serie_ori))
            
        elif intensite_struc_cst.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            date_base=2000
            l_somme=['toccfagrcst', 'toccftracst']
            if serie[-3:-1]=='cc':
                if serie[-4]=='1':
                    l_somme = l_somme+['toccftercstcc','toccfrescstcc','toccfindcst']
                else:
                    l_somme = l_somme+['toccftercstcc','toccfrescstcc','toccfimacst']
                    calcul_sup=True
            else:
                if serie[-4]=='1':
                    l_somme = l_somme+['toccftercst','toccfrescst','toccfindcst']
                else:
                    l_somme = l_somme+['toccftercst','toccfrescst','toccfimacst']
                    calcul_sup=True
            odypy.write("resOdy = multiAffectation(resOdy, {}, {}, {}, poids=1000/recupSerie(resOdy,'pibxx',{}))\n".format(
                serie, l_somme, unite, date_base))
            
        elif VITOC_Branche.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            odypy.write("resOdy = calculVITOC_Branche(resOdy, {})\n".format(serie))
            
        elif VITOC_ED_Secteur.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            odypy.write("resOdy = calculVITOC_ED_Secteur(resOdy, {})\n".format(serie))
            
        elif VITOC_ED.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            odypy.write("resOdy = calculVITOC_ED(resOdy, {})\n".format(serie))
            
        elif series_EEG.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            serie1=param[1]
            unite=param[2]
            date_base=2000
            serie_base=serie1[:-1]+"[2000]'"
            odypy.write("resOdy = affectation(resOdy, {}, {}, {}, formule=lambda x : recupSerie(resOdy, {}, {})-x)\n".format(
                serie, serie1, unite, serie1, date_base))
    
        elif othcfind.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            unite=param[1]
            odypy.write("resOdy = multiAffectation(resOdy, {}, ['toccfind', '-toccfsid1', '-toccfchi', '-toccfmnm', '-toccfppp','-toccfmnf'], [{}])\n".format(
            serie, unite))
        
        elif series_lc.search(ligne):
            param=arguments.search(ligne).group().split(",")
            serie=param[0]
            txchg=param[1]
            unite=param[2]
            serie_mult = serie
            odypy.write("resOdy = affectationConv(resOdy, {}, {}, {}, '/', {})\n".format(
                serie, serie_mult, txchg, unite))
        
        else:
            odypy.write(ligne)
            odyreste.write(ligne)
            if re.search("CALC", ligne):
                non_trad += 1
                print(ligne)


print("Nb de lignes :", tot_lignes)
print("Lignes à vérifier (conditions et commentaires) :", lignes_spe)
print("Reste à traduire :", non_trad)

# %% [markdown]
# ## Nettoyeur

# %%
# with open("FichiersSQLTrad/ODYSEC_traduit.txt", "r") as ody1, open("FichiersSQLTrad/ODYSEC_clean.txt", "w") as ody2:
# with open("FichiersSQLTrad/ODYCO2_traduit.txt", "r") as ody1, open("FichiersSQLTrad/ODYCO2_clean.txt", "w") as ody2:
with open("FichiersSQLTrad/INDICODY_traduit.txt", "r") as ody1, open("FichiersSQLTrad/INDICODY_clean.txt", "w") as ody2:
    garder = True
    debut = ""
    for ligne in ody1:
        if re.search('DBMS', ligne) or re.search('ERREUR', ligne) or re.search('Correction', ligne):
            continue
        elif re.match("\t*--", ligne):
            if re.search("coment", ligne):
                ody2.write("#"+ligne[10:-2].upper()+"\n")
        elif re.search(".*/\*.*\*/.*", ligne) and not re.search("correction", ligne):
            ody2.write("#"+ligne[2:-3]+"\n")
        elif re.search(".*\*/.*", ligne):
            garder = True
        elif re.search(".*/\*.*", ligne):
            garder = False
        elif re.search(".*END.*", ligne):
            debut = debut[:-1]

        elif re.search(".*SELECT.*", ligne):
            try: 
                serie_test = arguments2.search(ligne).group()
            except AttributeError:
                try:
                    serie_test = "'"+test_serie.search(ligne).group()+"'"
                except AttributeError:
                    ody2.write(ligne)
            
        elif (re.search(".*IF \(?serie_existe.?.?\)?", ligne) or re.search(".*IF ser_existe", ligne)) and garder == True:
            if re.search("=0", ligne):
                ody2.write(debut+"if not recupSerie(resOdy,{}):\n".format(serie_test))
            elif re.search("=1", ligne):
                ody2.write(debut+"if recupSerie(resOdy,{}):\n".format(serie_test))
            elif re.search("=2", ligne):
                serie_test = serie_test.split(',')
                ody2.write(debut+"if recupSerie(resOdy,{}) & recupSerie(resOdy,{}):\n".format(serie_test[0], serie_test[1]))
            elif re.search("=3", ligne):
                serie_test = serie_test.split(',')
                ody2.write(debut+"if recupSerie(resOdy,{}) & recupSerie(resOdy,{}) & recupSerie(resOdy,{}):\n".format(serie_test[0], serie_test[1], serie_test[2]))
            elif re.search("=5", ligne):
                serie_test = serie_test.split(',')
                ody2.write(debut+"if recupSerie(resOdy,{}) & recupSerie(resOdy,{}) & recupSerie(resOdy,{}) & recupSerie(resOdy,{}) & recupSerie(resOdy,{}):\n".format(serie_test[0], serie_test[1], serie_test[2], serie_test[3], serie_test[4]))
            elif re.search(">", ligne):
                serie_test = serie_test.split(',')
                condition = "if recupSerie(resOdy,{}) ".format(serie_test[0])
                for serie in serie_test[1:]:
                    condition = condition + "& recupSerie(resOdy,{})".format(serie)    
                ody2.write(debut+condition+":\n")
            else:
                ody2.write(ligne)
            debut = debut+"\t"
            
        elif re.search(".*IF pays_cour.*", ligne) and garder == True:
            try:
                liste_pays = arguments.search(ligne).group()
            except:
                liste_pays = "'"+test_serie.search(ligne).group()+"'"
            if len(liste_pays.split(",")) > 1:
                if re.search("NOT", ligne):
                    ody2.write(debut+"if pays not in [{}]:\n".format(liste_pays))
                else:
                    ody2.write(debut+"if pays in [{}]:\n".format(liste_pays))
            else:
                if re.search("NOT", ligne):
                    ody2.write(debut+"if pays != {}:\n".format(liste_pays))
                else:
                    ody2.write(debut+"if pays == {}:\n".format(liste_pays))
            debut = debut+"\t"
        
#         elif re.search("elif", ligne):
#             liste_pays = arguments.search(ligne).group()
#             debut = debut[:-1]
#             if len(liste_pays.split(",")) > 1:
#                 ody2.write(debut+"elif pays in [{}]:\n".format(liste_pays))
#             else:
#                 ody2.write(debut+"elif pays == {}:\n".format(liste_pays))
#             debut = debut+"\t"
        
        elif re.search(".*ELSE.*", ligne) and garder == True:
            debut = debut[:-1]
            ody2.write(debut+"else:\n")
            debut = debut+"\t"
        
        else:
            if garder == True:
                ody2.write(debut+ligne)
